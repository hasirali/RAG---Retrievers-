# %%
# %pip install langchain-google-genai
# %pip install faiss-cpu
from langchain_community.vectorstores import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_core.documents import Document
# Out:
# Requirement already satisfied: langchain-google-genai in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (4.2.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.65.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-google-genai) (1.75.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.29 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-google-genai) (1.3.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.52.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.33.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (26.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: idna>=2.8 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (3.12)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (48.0.0)
# Requirement already satisfied: certifi in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.6.3)
# Requirement already satisfied: pycparser in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: faiss-cpu in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (1.13.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from faiss-cpu) (2.4.4)
# Requirement already satisfied: packaging in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from faiss-cpu) (26.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.vectorstores import FAISS

# Initialize OpenAI embeddings
embedding_model = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001",
)

# Step 2: Create the FAISS vector store from documents
vectorstore = FAISS.from_documents(
    documents=docs,
    embedding=embedding_model
)

# %%
# Sample documents
docs = [
    Document(page_content="LangChain makes it easy to work with LLMs."),
    Document(page_content="LangChain is used to build LLM based applications."),
    Document(page_content="Chroma is used to store and search document embeddings."),
    Document(page_content="Embeddings are vector representations of text."),
    Document(page_content="MMR helps you get diverse results when doing similarity search."),
    Document(page_content="LangChain supports Chroma, FAISS, Pinecone, and more."),
]

# %%
# Enable MMR in the retriever
retriever = vectorstore.as_retriever(
    search_type="mmr",                   # <-- This enables MMR
    search_kwargs={"k": 3, "lambda_mult": 0.5}  # k = top results, lambda_mult = relevance-diversity balance
)

# %%
query = "What is langchain?"
results = retriever.invoke(query)

# %%
query = "What is langchain?"
results = retriever.invoke(query)

# %%
for i, doc in enumerate(results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)
# Out:
# --- Result 1 ---
# LangChain is used to build LLM based applications.
#
# --- Result 2 ---
# MMR helps you get diverse results when doing similarity search.
#
# --- Result 3 ---
# LangChain supports Chroma, FAISS, Pinecone, and more.
