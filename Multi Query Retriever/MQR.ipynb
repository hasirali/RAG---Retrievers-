# %%
# %pip install langchain langchain-community langchain-core langchain-classic
from langchain_community.vectorstores import FAISS
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_core.documents import Document
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_classic.retrievers import MultiQueryRetriever
# Out:
# Requirement already satisfied: langchain in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (1.2.18)
# Requirement already satisfied: langchain-community in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (1.3.3)
# Requirement already satisfied: langchain-classic in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (1.0.7)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.10 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain) (1.1.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-community) (2.33.1)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-community) (0.8.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core) (0.0.15)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core) (26.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-classic) (1.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (4.0.3)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.12 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (1.0.13)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (3.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.12)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.2.25)
# Requirement already satisfied: greenlet>=1 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.5.0)
# Requirement already satisfied: anyio in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.13.0)
# Requirement already satisfied: httpcore==1.* in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain) (1.12.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\hasir\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.18

# %%
# Relevant health & wellness documents
all_docs = [
    Document(page_content="Regular walking boosts heart health and can reduce symptoms of depression.", metadata={"source": "H1"}),
    Document(page_content="Consuming leafy greens and fruits helps detox the body and improve longevity.", metadata={"source": "H2"}),
    Document(page_content="Deep sleep is crucial for cellular repair and emotional regulation.", metadata={"source": "H3"}),
    Document(page_content="Mindfulness and controlled breathing lower cortisol and improve mental clarity.", metadata={"source": "H4"}),
    Document(page_content="Drinking sufficient water throughout the day helps maintain metabolism and energy.", metadata={"source": "H5"}),
    Document(page_content="The solar energy system in modern homes helps balance electricity demand.", metadata={"source": "I1"}),
    Document(page_content="Python balances readability with power, making it a popular system design language.", metadata={"source": "I2"}),
    Document(page_content="Photosynthesis enables plants to produce energy by converting sunlight.", metadata={"source": "I3"}),
    Document(page_content="The 2022 FIFA World Cup was held in Qatar and drew global energy and excitement.", metadata={"source": "I4"}),
    Document(page_content="Black holes bend spacetime and store immense gravitational energy.", metadata={"source": "I5"}),
]

# %%
# Initialize OpenAI embeddings
embedding_model = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001",
)

# Create FAISS vector store
vectorstore = FAISS.from_documents(documents=all_docs, embedding=embedding_model)

# %%
# Create retrievers
similarity_retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 5})

# %%
multiquery_retriever = MultiQueryRetriever.from_llm(
    retriever=vectorstore.as_retriever(search_kwargs={"k": 5}),
    llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
)

# %%
# Query
query = "How to improve energy levels and maintain balance?"

# %%
# Retrieve results
similarity_results = similarity_retriever.invoke(query)
multiquery_results= multiquery_retriever.invoke(query)

# %%
for i, doc in enumerate(similarity_results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)

print("*"*150)

for i, doc in enumerate(multiquery_results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)
# Out:
# --- Result 1 ---
# Drinking sufficient water throughout the day helps maintain metabolism and energy.
#
# --- Result 2 ---
# The solar energy system in modern homes helps balance electricity demand.
#
# --- Result 3 ---
# Mindfulness and controlled breathing lower cortisol and improve mental clarity.
#
# --- Result 4 ---
# Consuming leafy greens and fruits helps detox the body and improve longevity.
#
# --- Result 5 ---
# Regular walking boosts heart health and can reduce symptoms of depression.
# ******************************************************************************************************************************************************
#
# --- Result 1 ---
# Drinking sufficient water throughout the day helps maintain metabolism and energy.
#
# --- Result 2 ---
# The solar energy system in modern homes helps balance electricity demand.
#
# --- Result 3 ---
# Mindfulness and controlled breathing lower cortisol and improve mental clarity.
#
# --- Result 4 ---
# Regular walking boosts heart health and can reduce symptoms of depression.
#
# --- Result 5 ---
# Consuming leafy greens and fruits helps detox the body and improve longevity.
#
# --- Result 6 ---
# Deep sleep is crucial for cellular repair and emotional regulation.
